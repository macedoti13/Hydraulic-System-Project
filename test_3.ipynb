# %%
import pandas as pd

pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', None)

# %%
q2 = pd.read_parquet("data/questions_datasets/question_2_dataset.parquet")
q2.head(100)
# Out:
#     hour  avg_weekday_output_flow  avg_weekend_output_flow
# 0      0                28.017858                30.630013
# 1      1                25.504243                27.019786
# 2      2                25.460058                25.009778
# 3      3                23.178671                24.169199
# 4      4                23.729474                24.319796
# 5      5                27.374432                27.062895
# 6      6                30.741613                28.136149
# 7      7                33.857773                30.997651
# 8      8                35.803129                34.450577
# 9      9                35.865222                39.713231
# 10    10                36.862940                42.343162
# 11    11                39.140555                45.977871
# 12    12                40.319236                47.033645
# 13    13                42.113334                46.129771
# 14    14                39.139701                44.009884
# ...

# %%
q3 = pd.read_parquet("data/questions_datasets/question_3_dataset.parquet")
q3.head(100)
# Out:
#      pump average_time_used_peak_hours average_time_used_offpeak_hours
# 0  pump_1       1 hours and 24 minutes          7 hours and 57 minutes
# 1  pump_2       0 hours and 38 minutes           5 hours and 9 minutes
